# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

from tensorflow import keras
from keras.layers import Dense, Conv2D, MaxPooling2D, Flatten
from keras import Sequential
from keras.datasets import cifar10

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()

# %%
x_train = x_train.astype('float64')
x_test = x_test.astype('float64')

x_train /= 255
x_test /= 255

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
x_train = x_train.reshape(x_train.shape[0], 32, 32, 3)
x_test = x_test.reshape(x_test.shape[0], 32, 32, 3)

# %%
y_train = keras.utils.to_categorical(y_train, 10)
y_test = keras.utils.to_categorical(y_test, 10)

# %%
model = Sequential()

# Conv Layer 1
model.add(Conv2D(6, kernel_size = (5, 5), strides = 1, 
                 padding = 'valid', activation = 'relu', 
                 input_shape = (32, 32, 3)))

# Pooling Layer
model.add(MaxPooling2D(pool_size = (2, 2), strides = 2, padding = 'valid'))

# Conv Layer 2
model.add(Conv2D(16, kernel_size = (5, 5), strides = 1, 
                 padding = 'valid', activation = 'relu'))

# Pooling Layer
model.add(MaxPooling2D(pool_size = (2, 2), strides = 2, padding = 'valid'))

# Flatten
model.add(Flatten())

# Fully connected layer (DNN)
# 1st Layer
model.add(Dense(120, activation = 'relu'))

#2nd Layer
model.add(Dense(84, activation = 'relu'))

# Output layer
model.add(Dense(10, activation = 'softmax'))

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_2 (Conv2D)               │ (None, 28, 28, 6)      │           456 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 14, 14, 6)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 10, 10, 16)     │         2,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 5, 5, 16)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 400)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 120)            │        48,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 84)             │        10,164 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 10)             │           850 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 62,006 (242.21 KB)
#  Trainable params: 62,006 (242.21 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer = 'adam', loss = keras.losses.categorical_crossentropy, metrics = ['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs = 100, 
                    batch_size = 64, validation_data = (x_test, y_test))
# Out:
# Epoch 1/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.3168 - loss: 1.8593 - val_accuracy: 0.4696 - val_loss: 1.4534
# Epoch 2/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.4815 - loss: 1.4299 - val_accuracy: 0.5216 - val_loss: 1.3651
# Epoch 3/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.5373 - loss: 1.2942 - val_accuracy: 0.5385 - val_loss: 1.2879
# Epoch 4/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.5694 - loss: 1.2039 - val_accuracy: 0.5658 - val_loss: 1.2304
# Epoch 5/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.5935 - loss: 1.1444 - val_accuracy: 0.5584 - val_loss: 1.2574
# Epoch 6/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.6169 - loss: 1.0778 - val_accuracy: 0.5950 - val_loss: 1.1506
# Epoch 7/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.6355 - loss: 1.0277 - val_accuracy: 0.6035 - val_loss: 1.1224
# Epoch 8/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.6467 - loss: 0.9929 - val_accuracy: 0.6146 - val_loss: 1.1079
# Epoch 9/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.6632 - loss: 0.9517 - val_accuracy: 0.6271 - val_loss: 1.0770
# Epoch 10/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.6836 - loss: 0.9040 - val_accuracy: 0.6288 - val_loss: 1.0805
# Epoch 11/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.6939 - loss: 0.8699 - val_accuracy: 0.6234 - val_loss: 1.1139
# Epoch 12/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.7042 - loss: 0.8355 - val_accuracy: 0.6247 - val_loss: 1.1208
# Epoch 13/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - accuracy: 0.7079 - loss: 0.8222 - val_accuracy: 0.6265 - val_loss: 1.1131
# Epoch 14/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0
100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9466 - loss: 0.1499 - val_accuracy: 0.5757 - val_loss: 3.6454
# Epoch 79/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.9388 - loss: 0.1615 - val_accuracy: 0.5720 - val_loss: 3.6831
# Epoch 80/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9398 - loss: 0.1670 - val_accuracy: 0.5733 - val_loss: 3.6188
# Epoch 81/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.9361 - loss: 0.1759 - val_accuracy: 0.5675 - val_loss: 3.8410
# Epoch 82/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9451 - loss: 0.1535 - val_accuracy: 0.5699 - val_loss: 3.7323
# Epoch 83/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9491 - loss: 0.1435 - val_accuracy: 0.5714 - val_loss: 3.8013
# Epoch 84/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9458 - loss: 0.1511 - val_accuracy: 0.5678 - val_loss: 3.8781
# Epoch 85/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9486 - loss: 0.1401 - val_accuracy: 0.5705 - val_loss: 3.8605
# Epoch 86/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9425 - loss: 0.1544 - val_accuracy: 0.5754 - val_loss: 3.8923
# Epoch 87/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9430 - loss: 0.1579 - val_accuracy: 0.5724 - val_loss: 3.9651
# Epoch 88/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9421 - loss: 0.1589 - val_accuracy: 0.5744 - val_loss: 3.9560
# Epoch 89/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9427 - loss: 0.1569 - val_accuracy: 0.5770 - val_loss: 4.0900
# Epoch 90/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9379 - loss: 0.1789 - val_accuracy: 0.5660 - val_loss: 4.1605
# Epoch 91/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9516 - loss: 0.1336 - val_accuracy: 0.5680 - val_loss: 4.0697
# Epoch 92/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9529 - loss: 0.1323 - val_accuracy: 0.5704 - val_loss: 4.1701
# Epoch 93/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9499 - loss: 0.1411 - val_accuracy: 0.5731 - val_loss: 4.1302
# Epoch 94/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9577 - loss: 0.1189 - val_accuracy: 0.5696 - val_loss: 4.1969
# Epoch 95/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9501 - loss: 0.1403 - val_accuracy: 0.5717 - val_loss: 4.2642
# Epoch 96/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9445 - loss: 0.1547 - val_accuracy: 0.5694 - val_loss: 4.1678
# Epoch 97/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9650 - loss: 0.1005 - val_accuracy: 0.5676 - val_loss: 4.4070
# Epoch 98/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9423 - loss: 0.1606 - val_accuracy: 0.5671 - val_loss: 4.4221
# Epoch 99/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9537 - loss: 0.1296 - val_accuracy: 0.5627 - val_loss: 4.4531
# Epoch 100/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9506 - loss: 0.1395 - val_accuracy: 0.5709 - val_loss: 4.4132

# %%
x = np.linspace(1, 100, 100)

fig, axs = plt.subplots(2, 2, figsize = (12, 10))

axs[0, 0].plot(x, history.history['accuracy'], 'b')
axs[0, 0].set_title('Traing Accuracy')
axs[0, 0].set_xlabel('Epochs')
axs[0, 0].set_ylabel('Accuracy')

axs[0, 1].plot(x, history.history['loss'], 'r')
axs[0, 1].set_title('Traing Loss')
axs[0, 1].set_xlabel('Epochs')
axs[0, 1].set_ylabel('Loss')

axs[1, 0].plot(x, history.history['val_accuracy'], 'g')
axs[1, 0].set_title('Validation Accuracy')
axs[1, 0].set_xlabel('Epochs')
axs[1, 0].set_ylabel('Accuracy')

axs[1, 1].plot(x, history.history['loss'], 'k')
axs[1, 1].set_title('Validation Loss')
axs[1, 1].set_xlabel('Epochs')
axs[1, 1].set_ylabel('Loss')

plt.tight_layout()
plt.show()
